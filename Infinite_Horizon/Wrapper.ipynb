# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %%
import numpy as np

class InfiniteHorizonEnv(gym.Env):
    def __init__(self, gamma=0.99):
        super().__init__()
        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32)
        self.state = 0
        self.gamma = gamma  # Discount rate
        self.current_step = 0

    def step(self, action):
        self.state += -1 if action == 0 else 1
        immediate_reward = abs(self.state)  # Immediate reward without discounting
        
        # Apply discounting to the immediate reward
        discounted_reward = immediate_reward * (self.gamma ** self.current_step)
        self.current_step += 1

        info = {'immediate_reward': immediate_reward}  # Keep the immediate reward in the info for reference
        return np.array([self.state]).astype(np.float32), discounted_reward, False, info

    def reset(self):
        self.state = 0
        self.current_step = 0
        return np.array([self.state]).astype(np.float32)
    
    def render(self, mode='human'):
        print(f"State: {self.state}")


from gym.envs.registration import register

register(
    id='InfiniteHorizonEnv-v0',  # Use an id that uniquely identifies your env
    entry_point='utils.env:InfiniteHorizonEnv',  # Point to where your environment is defined. Use the format 'folder.filename:ClassName'
)

# %%
from gym.envs.registration import register
from gym import spaces 

env = gym.make('InfiniteHorizonEnv-v0')
observation = env.reset()
for _ in range(1000):  # Arbitrary large number to simulate the "infinite" aspect
    action = env.action_space.sample()  # Replace with your model's action prediction
    observation, reward, done, info = env.step(action)
    env.render()
env.close()
# Out:
# State: -1
# State: 0
# State: 1
# State: 2
# State: 3
# State: 2
# State: 3
# State: 2
# State: 1
# State: 2
# State: 3
# State: 2
# State: 3
# State: 2
# State: 3
# State: 4
# State: 3
# State: 4
# State: 3
# State: 2
# State: 3
# State: 4
# State: 3
# State: 4
# State: 5
# State: 4
# State: 3
# State: 4
# State: 3
# State: 4
# State: 5
# State: 4
# State: 3
# State: 4
# State: 5
# State: 4
# State: 3
# State: 2
# State: 1
# State: 2
# State: 1
# State: 2
# State: 3
# State: 4
# State: 3
# State: 2
# State: 1
# State: 0
# State: -1
# State: 0
# State: -1
# State: 0
# State: 1
# State: 0
# State: 1
# State: 2
# State: 3
# State: 4
# State: 3
# State: 4
# State: 3
# State: 4
# State: 3
# State: 2
# State: 1
# State: 0
# State: -1
# State: -2
# State: -1
# State: 0
# State: -1
# State: 0
# State: -1
# State: 0
# State: 1
# State: 2
# State: 1
# State: 0
# State: -1
# State: 0
# State: -1
# State: 0
# State: -1
# State: 0
# State: 1
# State: 2
# State: 1
# State: 0
# State: -1
# State: 0
# State: 1
# State: 0
# State: -1
# State: 0
# State: -1
# State: 0
# State: 1
# State: 0
# State: 1
# State: 2
# State: 1
# State: 0
# State: 1
# State: 0
# State: 1
# State: 0
# State: -1
# State: -2
# State: -1
# State: -2
# State: -3
# State: -2
# State: -1
# State: -2
# State: -3
# State: -2
# State: -1
# State: 0
# State: 1
# State: 2
# State: 3
# State: 4
# State: 5
# State: 6
# State: 7
# State: 6
# State: 7
# State: 8
# State: 7
# State: 6
# State: 7
# State: 8
# State: 9
# State: 10
# State: 11
# State: 12
# State: 11
# State: 12
# State: 11
# State: 12
# State: 11
# State: 10
# State: 9
# State: 8
# State: 9
# State: 10
# State: 11
# State: 10
# State: 11
# State: 10
# State: -1
# State: 0
# State: -1
# State: -2
# State: -3
# State: -4
# State: -3
# State: -4
# State: -5
# State: -6
# State: -7
# State: -8
# State: -9
# State: -8
# State: -7
# State: -8
# State: -9
# State: -8
# State: -7
# State: -6
# State: -5
# State: -6
# State: -7
# State: -6
# State: -5
# State: -6
# State: -5
# State: -4
# State: -5
# State: -4
# State: -3
# State: -2
# State: -1
# State: 0
# State: -1
# State: 0
# State: -1
# State: -2
# State: -1
# State: 0
# State: -1
# State: 0
# State: 1
# State: 2
# State: 1
# State: 0
# State: -1
# State: 0
# State: -1
# State: 0
# State: 1
# State: 0
# State: -1
# State: -2
# State: -3
# State: -2
# State: -3
# State: -4
# State: -5
# State: -6
# State: -5
# State: -6
# State: -5
# State: -6
# State: -5
# State: -4
# State: -5
# State: -4
# State: -5
# State: -4
# State: -5
# State: -6
# State: -5
# State: -4
# State: -3
# State: -2
# State: -1
# State: 0
# State: 1
# State: 2
# State: 1
# State: 2
# State: 1
# State: 0
# State: -1
# State: -2
# State: -3
# State: -4
# State: -3
# State: -2
# State: -3
# State: -2
# State: -3
# State: -4
# State: -5
# State: -6
# State: -5
# State: -6
# State: -7
# State: -8
# State: -9
# State: -10
# State: -9
# State: -10
# State: -9
# State: -10
# State: -11
# State: -10
# State: -11
# State: -10
# State: -11
# State: -10
# State: -11
# State: -12
# State: -13
# State: -14
# State: -13
# State: -14
# State: -15
# State: -14
# State: -13
# State: -12
# State: -11
# State: -10
# State: -9
# State: -10
# State: -11
# State: -12
# State: -13
# State: -14
# State: -13
# State: -14
# State: -15
# State: -16
# State: -15
# State: -14
# State: -15
# State: -16
# State: -15
# State: -14
# State: -15
# State: -16
# State: -15
# State: -14
# State: -13
# State: -12
# State: -11
# State: -12
# State: -11
# State: -12
# State: -11
# State: -10
# State: -9
# State: -10
# State: -11
# State: -12
# State: -11
# State: -12
# State: -11
# State: -10
# State: -11
# State: -10
# State: -11
# State: -12
# State: -11
# State: -12
# State: -11
# State: -12
# State: -13
# State: -12
# State: -13
# State: -14
# State: -13
# State: -12
# State: -13
# State: -14
# State: -15
# State: -14
# State: -15
# State: -14
# State: -13
# State: -12
# State: -13
# State: -14
# State: -15
# State: -14
# State: -13
# State: -14
# State: -15
# State: -14
# State: -13
# State: -14
# State: -15
# State: -14
# State: -13
# State: -14
# State: -13
# State: -14
# State: -15
# State: -14
# State: -13
# State: -12
# State: -13
# State: -12
# State: -11
# State: -12
# State: -11
# State: -10
# State: -11
# State: -10
# State: -9
# State: -10
# State: -9
# State: -8
# State: -9
# State: -8
# State: -7
# State: -6
# State: -7
# State: -6
# State: -5
# State: -4
# State: -3
# State: -2
# State: -3
# State: -2
# State: -1
# State: -2
# State: -1
# State: -2
# State: -3
# State: -4
# State: -5
# State: -6
# State: -7
# State: -8
# State: -9
# State: -10
# State: -11
# State: -10
# State: -11
# State: -12
# State: -13
# State: -12
# State: -13
# State: -12
# State: -13
# State: -12
# State: -11
# State: -10
# State: -9
# State: -10
# State: -11
# State: -10
# State: -11
# State: -10
# State: -11
# State: -12
# State: -13
# State: -12
# State: -11
# State: -12
# State: -13
# State: -12
# State: -11
# State: -12
# State: -13
# State: -14
# State: -13
# State: -12
# State: -11
# State: -10
# State: -9
# State: -10
# State: -11
# State: -12
# State: -13
# State: -12
# State: -11
# State: -12
# State: -13
# State: -12
# State: -11
# State: -12
# State: -13
# State: -12
# State: -11
# State: -10
# State: -9
# State: -10
# State: -11
# State: -10
# State: -9
# State: -10
# State: -9
# State: -8
# State: -7
# State: -6
# State: -5
# State: -4
# State: -5
# State: -6
# State: -5
# State: -6
# State: -7
# State: -6
# State: -5
# State: -4
# State: -3
# State: -4
# State: -5
# State: -6
# State: -7
# State: -6
# State: -5
# State: -4
# State: -5
# State: -6
# State: -7
# State: -6
# State: -5
# State: -4
# State: -5
# State: -6
# State: -7
# State: -6
# State: -7
# State: -8
# State: -7
# State: -6
# State: -5
# State: -4
# State: -3
# State: -2

# %%
def evaluate_policy(env, policy, gamma=0.99, threshold=0.001):
    value_table = np.zeros(env.observation_space.n)
    while True:
        delta = 0
        for state in range(env.observation_space.n):
            v = 0
            for action, action_prob in enumerate(policy[state]):
                for state_prob, next_state, reward, done in env.P[state][action]:
                    v += action_prob * state_prob * (reward + gamma * value_table[next_state])
            delta = max(delta, np.abs(value_table[state] - v))
            value_table[state] = v
        if delta < threshold:
            break
    return value_table

# %%
def evaluate_policy(env, policy, gamma=0.99, threshold=0.001):
    value_table = np.zeros(env.observation_space.n)
    while True:
        delta = 0
        for state in range(env.observation_space.n):
            v = 0
            for action, action_prob in enumerate(policy[state]):
                for state_prob, next_state, reward, done in env.P[state][action]:
                    v += action_prob * state_prob * (reward + gamma * value_table[next_state])
            delta = max(delta, np.abs(value_table[state] - v))
            value_table[state] = v
        if delta < threshold:
            break
    return value_table

# %%
import gym


env = gym.make('InfiniteHorizonEnv-v0')
observation = env.reset()
for _ in range(1000):  # Arbitrary large number to simulate the "infinite" aspect
    action = env.action_space.sample()  # Replace with your model's action prediction
    observation, reward, done, info = env.step(action)
    env.render()
env.close()
# Out:
# State: -1
# State: 0
# State: 1
# State: 2
# State: 3
# State: 2
# State: 3
# State: 2
# State: 3
# State: 4
# State: 5
# State: 6
# State: 5
# State: 6
# State: 7
# State: 6
# State: 5
# State: 4
# State: 5
# State: 6
# State: 7
# State: 8
# State: 7
# State: 6
# State: 7
# State: 8
# State: 7
# State: 8
# State: 9
# State: 10
# State: 9
# State: 8
# State: 9
# State: 8
# State: 7
# State: 8
# State: 9
# State: 10
# State: 9
# State: 10
# State: 11
# State: 12
# State: 13
# State: 12
# State: 11
# State: 12
# State: 13
# State: 14
# State: 13
# State: 14
# State: 15
# State: 16
# State: 17
# State: 18
# State: 17
# State: 18
# State: 19
# State: 20
# State: 21
# State: 22
# State: 21
# State: 22
# State: 23
# State: 24
# State: 23
# State: 22
# State: 23
# State: 22
# State: 23
# State: 22
# State: 23
# State: 24
# State: 23
# State: 24
# State: 23
# State: 22
# State: 21
# State: 22
# State: 23
# State: 24
# State: 25
# State: 26
# State: 25
# State: 24
# State: 23
# State: 12
# State: 13
# State: 14
# State: 15
# State: 16
# State: 17
# State: 18
# State: 19
# State: 18
# State: 17
# State: 16
# State: 17
# State: 18
# State: 19
# State: 18
# State: 17
# State: 16
# State: 17
# State: 16
# State: 15
# State: 14
# State: 13
# State: 14
# State: 15
# State: 14
# State: 15
# State: 16
# State: 17
# State: 16
# State: 17
# State: 16
# State: 15
# State: 16
# State: 17
# State: 16
# State: 17
# State: 16
# State: 15
# State: 14
# State: 13
# State: 12
# State: 11
# State: 10
# State: 9
# State: 10
# State: 11
# State: 10
# State: 9
# State: 8
# State: 9
# State: 10
# State: 9
# State: 8
# State: 7
# State: 6
# State: 5
# State: 6
# State: 7
# State: 6
# State: 7
# State: 8
# State: 7
# State: 8
# State: 9
# State: 10
# State: 9
# State: 10
# State: 9
# State: 8
# State: 7
# State: 8
# State: 9
# State: 8
# State: 7
# State: 8
# State: 9
# State: 10
# State: 9
# State: 8
# State: 9
# State: 10
# State: 9
# State: 10
# State: 9
# State: 10
# State: 11
# State: 12
# State: 11
# State: 12
# State: 11
# State: 10
# State: 9
# State: 8
# State: 9
# State: 10
# State: 9
# State: 8
# State: 7
# State: 6
# State: 7
# State: 6
# State: 5
# State: 6
# State: 7
# State: 8
# State: 7
# State: 8
# State: 9
# State: 8
# State: 7
# State: 8
# State: 9
# State: 8
# State: 7
# State: 6
# State: 7
# State: 6
# State: 5
# State: 4
# State: 5
# State: 4
# State: 5
# State: 6
# State: 5
# State: 6
# State: 7
# State: 6
# State: 7
# State: 8
# State: 7
# State: 6
# State: 7
# State: 8
# State: 9
# State: 8
# State: 7
# State: 8
# State: 9
# State: 8
# State: 9
# State: 10
# /home/bcl/.conda/envs/gmfg/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/bcl/.conda/envs/gmfg/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /home/bcl/.conda/envs/gmfg/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# /home/bcl/.conda/envs/gmfg/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/bcl/.conda/envs/gmfg/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):

# %%
env_id = "CartPole-v1"
# Vectorized environments allow for parallel execution of multiple instances
env = make_vec_env(env_id, n_envs=4)

# %%
model = PPO("MlpPolicy", env, gamma=0.9, verbose=1)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | 21.9     |
# | time/              |          |
# |    fps             | 1601     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 8192     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.5         |
# |    ep_rew_mean          | 34.5         |
# | time/                   |              |
# |    fps                  | 1083         |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0144494325 |
# |    clip_fraction        | 0.203        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | -0.0024      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.371        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0245      |
# |    value_loss           | 3.97         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 77.8       |
# |    ep_rew_mean          | 77.8       |
# | time/                   |            |
# |    fps                  | 1024       |
# |    iterations           | 3          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02105991 |
# |    clip_fraction        | 0.314      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.635     |
# |    explained_variance   | 0.645      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.602      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0491    |
# |    value_loss           | 1.36       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.024372902 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.53        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0354     |
# |    value_loss           | 1.22        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 173        |
# |    ep_rew_mean          | 173        |
# | time/                   |            |
# |    fps                  | 1022       |
# |    iterations           | 5          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03331456 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.509     |
# |    explained_variance   | 0.62       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.186      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0234    |
# |    value_loss           | 0.598      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 1001        |
# |    iterations           | 6           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011341447 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.165       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.276       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 983         |
# |    iterations           | 7           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009525891 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0247      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 321         |
# | time/                   |             |
# |    fps                  | 980         |
# |    iterations           | 8           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004121258 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.203       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000173   |
# |    value_loss           | 0.0968      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | 331         |
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 9           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003421264 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00041     |
# |    value_loss           | 0.0515      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 325          |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 10           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0039318856 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.471       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00452     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 0.0373       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 293         |
# |    ep_rew_mean          | 293         |
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 11          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004651445 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.473      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00105    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.000222    |
# |    value_loss           | 0.028       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 275           |
# |    ep_rew_mean          | 275           |
# | time/                   |               |
# |    fps                  | 947           |
# |    iterations           | 12            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00061804964 |
# |    clip_fraction        | 0.0142        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.478        |
# |    explained_variance   | 0.972         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00345       |
# |    n_updates            | 110           |
# |    policy_gradient_loss | 0.00146       |
# |    value_loss           | 0.0206        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 275          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 13           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0050739115 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0226       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000412    |
# |    value_loss           | 0.0086       |
# ------------------------------------------

# %%
model.save("ppo_cartpole")

# %%
model1 = PPO.load("model/ppo_cartpole")

# %%
env1 = gym.make("CartPole-v1")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 6
#       4     action, _states = model.predict(obs, deterministic=True)
#       5     obs, rewards, dones, info = env.step(action)
# ----> 6     env.render()
#       7 env.close()
#
# File ~/.conda/envs/gmfg/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:103, in DummyVecEnv.render(self, mode)
#      96 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      97     """
#      98     Gym environment rendering. If there are multiple environments then
#      99     they are tiled together in one image via ``BaseVecEnv.render()``.
#     100
#     101     :param mode: The rendering type.
#     102     """
# --> 103     return super().render(mode=mode)
#
# File ~/.conda/envs/gmfg/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:257, in VecEnv.render(self, mode)
#     255 images = self.get_images()
#     256 # Create a big image by tiling images from subprocesses
# --> 257 bigimg = tile_images(images)  # type: ignore[arg-type]
#     259 if mode == "human":
#     260     # Display it using OpenCV
#     261     import cv2
#
# File ~/.conda/envs/gmfg/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:39, in tile_images(images_nhwc)
#      37 # new_width was named W before
#      38 new_width = int(np.ceil(float(n_images) / new_height))
# ---> 39 img_nhwc = np.array(list(img_nhwc) + [img_nhwc[0] * 0 for _ in range(n_images, new_height * new_width)])
#      40 # img_HWhwc
#      41 out_image = img_nhwc.reshape((new_height, new_width, height, width, n_channels))
#
# KeyboardInterrupt:
